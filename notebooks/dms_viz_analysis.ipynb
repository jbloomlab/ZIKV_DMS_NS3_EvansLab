# %% [markdown]
# # Interactive Protein Structures
#
# Below, I'm making the visualization JSON files for [`dms-viz`](https://dms-viz.github.io/v0/) to explore the data on the open and closed confirmation of NS2B/NS3.
#
# To run this notebook, create and activate the environment in `data/dms-viz/environment.yml`:
#
# ```bash
# conda env create -f data/dms-viz/environment.yml
# conda activate dms-viz
# ```
#
# To view the interactive structures with the `log2effect`, download the `JSON` file (`/data/dms-viz/output/ZIKV-NS2B-NS3-DMS.json`) and upload it to [`dms-viz`](https://dms-viz.github.io/v0/). [Here](https://dms-viz.github.io/dms-viz-docs/) are instructions for using the web tool.

# %%
import pandas as pd
import os
import subprocess

# %% [markdown]
# ## Check out the commands
#
# What are the commands that we're running?

# %%
commands = pd.read_csv('../data/dms-viz/datasets.csv')
commands.head()
# Out:
#                                          input  \
# 0  ../data/dms-viz/input/ZIKV_NS2B_NS3_DMS.csv
# 1  ../data/dms-viz/input/ZIKV_NS2B_NS3_DMS.csv
#
#                                     sitemap                    name  \
# 0  ../data/dms-viz/sitemap/5GJ4_sitemap.csv    ZIKV NS2B-NS3 (Open)
# 1  ../data/dms-viz/sitemap/5LC0_sitemap.csv  ZIKV NS2B-NS3 (Closed)
#
#        metric   metric_name structure included_chains excluded_chains  \
# 0  log2effect  Log2(Effect)      5GJ4         polymer            none
# 1  log2effect  Log2(Effect)      5LC0         polymer            none
#
#                         title exclude_amino_acids
# 0    ZIKV NS2B-NS3 (Open) DMS                   *
# 1  ZIKV NS2B-NS3 (Closed) DMS                   *

# %% [markdown]
# ## Run `configure-dms-viz`
#
# Run the `configure-dms-viz` command for each structure that we want to visualize.

# %%
def create_viz_json(input_df, sitemap_df, output_path, **kwargs):
    """
    Creates a visualization JSON file for a given experiment/dataset.

    Parameters
    ----------
    input_df : str
        Path to the input dataframe CSV (--input).
    sitemap_df : str
        Path to the sitemap dataframe CSV (--sitemap).
    output_path : str
        Path to the output path JSON (--output).

    Returns
    -------
    None
        Executes a subprocess command and does not return any value.
    """

    command = f"""
    configure-dms-viz format \
        --input "{input_df}" \
        --sitemap "{sitemap_df}" \
        --output "{output_path}" \
    """
    for key, value in kwargs.items():
        command += f' --{key} "{value}"'
    subprocess.run(command, shell=True, check=True)


def combine_jsons(input_files, output_file):
    """
    Combines multiple JSON files into a single file.

    Parameters
    ----------
    input_files : list of str
        List of paths to the input JSON files.
    output_file : str
        Path where the combined JSON should be saved.

    Returns
    -------
    None
        Executes a subprocess command and does not return any value.
    """
    command = f"""
    configure-dms-viz join \
        --input "{', '.join(input_files)}" \
        --output "{output_file}"
    """
    subprocess.run(command, shell=True, check=True)

# %%
# Generate JSONs for each command
viz_jsons = []
for row in commands.itertuples():
    arguments = {
        key.replace("_", "-"): value
        for key, value in row._asdict().items()
        if key not in ["input", "sitemap", "Index"]
    }
    output_path = f"../data/dms-viz/output/{row.name}.json"
    create_viz_json(row.input, row.sitemap, output_path, **arguments)
    viz_jsons.append(output_path)

# Combine JSONs into a single file
combine_jsons(viz_jsons, "../data/dms-viz/output/ZIKV-NS2B-NS3-DMS.json")
# Out:
# Formatting data for visualization using the 'log2effect' column from '../data/dms-viz/input/ZIKV_NS2B_NS3_DMS.csv'...
#
# Using sitemap from '../data/dms-viz/sitemap/5GJ4_sitemap.csv'.
# About 99.49% (195 of 196) of the wildtype residues in the data match the corresponding residues in the structure.
# About 36.36% (112 of 308) of the data sites are missing from the structure.
#
# Success! The visualization JSON was written to '../data/dms-viz/output/ZIKV NS2B-NS3 (Open).json'
#
# Formatting data for visualization using the 'log2effect' column from '../data/dms-viz/input/ZIKV_NS2B_NS3_DMS.csv'...
#
# Using sitemap from '../data/dms-viz/sitemap/5LC0_sitemap.csv'.
# About 98.44% (189 of 192) of the wildtype residues in the data match the corresponding residues in the structure.
# About 37.66% (116 of 308) of the data sites are missing from the structure.
#
# Success! The visualization JSON was written to '../data/dms-viz/output/ZIKV NS2B-NS3 (Closed).json'
#
# Success! 2 JSON files were merged and saved to '../data/dms-viz/output/ZIKV-NS2B-NS3-DMS.json'
